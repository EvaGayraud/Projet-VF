# %%
from pathlib import Path
import sys

PROJECT_PATH = Path.cwd().parent / "projet_vf"
sys.path.append(str(PROJECT_PATH))

# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from model import regression
from data_loader import load_house_attributes
from data_sources import source_choice
from processing_attributes import process_house_attributes

# %%
PICKLE_DATASET_PATH = "_tmp_dataset.pkl"

try:
    df = pd.read_pickle(PICKLE_DATASET_PATH)
except FileNotFoundError:
    df = source_choice()
    df.to_pickle(PICKLE_DATASET_PATH)
# Out:
# Downloading DVF files
# Convert to csv

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 169852 entries, 2405430 to 2939476
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   No disposition             169852 non-null  int64
#  1   Date mutation              169852 non-null  datetime64[ns]
#  2   Nature mutation            169852 non-null  object
#  3   Valeur fonciere            169852 non-null  float64
#  4   Type de voie               169852 non-null  object
#  5   Code postal                169852 non-null  float64
#  6   Commune                    169852 non-null  object
#  7   Code departement           169852 non-null  object
#  8   Code commune               169852 non-null  int64
#  9   Section                    169852 non-null  object
#  10  Nombre de lots             169852 non-null  int64
#  11  Type local                 169852 non-null  object
#  12  Surface reelle bati        169852 non-null  float64
#  13  Nombre pieces principales  169852 non-null  float64
#  14  year                       169852 non-null  int64
#  15  months                     169852 non-null  int64
#  16  day                        169852 non-null  int64
#  17  Prix au m²                 169852 non-null  float64
# dtypes: datetime64[ns](1), float64(5), int64(6), object(6)
# memory usage: 24.6+ MB

# %%
df.describe()
# Out:
#        No disposition  Valeur fonciere    Code postal   Code commune  \
# count   169852.000000     1.698520e+05  169852.000000  169852.000000
# mean         1.007501     5.464244e+05   75013.450145     113.450145
# std          0.192903     5.367971e+05       4.799017       4.799017
# min          1.000000     8.000000e+03   75001.000000     101.000000
# 25%          1.000000     2.500000e+05   75011.000000     111.000000
# 50%          1.000000     3.980000e+05   75015.000000     115.000000
# 75%          1.000000     6.500000e+05   75017.000000     117.000000
# max         24.000000     2.850000e+07   75020.000000     120.000000
#
#        Nombre de lots  Surface reelle bati  Nombre pieces principales  \
# count   169852.000000        169852.000000              169852.000000
# mean         1.677937            53.775510                   2.406348
# std          0.827844            41.059145                   1.305421
# min          0.000000             2.000000                   0.000000
# 25%          1.000000            28.000000                   1.000000
# 50%          2.000000            43.000000                   2.000000
# 75%          2.000000            67.000000                   3.000000
# max         27.000000          1500.000000                  23.000000
#
#                 year         months            day     Prix au m²
# count  169852.000000  169852.000000  169852.000000  169852.000000
# mean     2017.950357       6.656872      16.646616    9986.923786
# std         1.370735       3.395307       8.895145    3413.303980
# min      2016.000000       1.000000       1.000000    1500.000000
# 25%      2017.000000       4.000000       9.000000    7940.000000
# 50%      2018.000000       7.000000      17.000000    9558.823529
# 75%      2019.000000      10.000000      25.000000   11474.358974
# max      2020.000000      12.000000      31.000000   25000.000000

# %%
plt.figure(figsize=(10, 10))
sns.pairplot(df[['Valeur fonciere', 'Surface reelle bati', 'Nombre pieces principales', 'Type local']],
             hue='Type local')

# %%
corr = df.corr()
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
train, test = train_test_split(df, test_size=0.25, random_state=42)

# %%
print('Training Shape:', train.shape)
print('Testing Shape:', test.shape)
# Out:
# Training Shape: (127389, 18)
# Testing Shape: (42463, 18)

# %%
data_processed = process_house_attributes(df)

# %%
train_x = train[data_processed]
test_x = train[data_processed]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-ed1694edb7c1> in <module>
# ----> 1 train_x, test_x = process_house_attributes(df_paris, train, test)
#
# ~\PycharmProjects\Projet-VF\projet_vf\processing_attributes.py in process_house_attributes(df, train, test)
#      11
#      12     pca = PCA()
# ---> 13     pca.fit(df)
#      14     transformed = pca.transform(df)
#      15
#
# c:\users\evaga\anaconda3\envs\projet-dvf\lib\site-packages\sklearn\decomposition\_pca.py in fit(self, X, y)
#     357             Returns the instance itself.
#     358         """
# --> 359         self._fit(X)
#     360         return self
#     361
#
# c:\users\evaga\anaconda3\envs\projet-dvf\lib\site-packages\sklearn\decomposition\_pca.py in _fit(self, X)
#     402                             'TruncatedSVD for a possible alternative.')
#     403
# --> 404         X = self._validate_data(X, dtype=[np.float64, np.float32],
#     405                                 ensure_2d=True, copy=self.copy)
#     406
#
# c:\users\evaga\anaconda3\envs\projet-dvf\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     419             out = X
#     420         elif isinstance(y, str) and y == 'no_validation':
# --> 421             X = check_array(X, **check_params)
#     422             out = X
#     423         else:
#
# c:\users\evaga\anaconda3\envs\projet-dvf\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# c:\users\evaga\anaconda3\envs\projet-dvf\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     595
#     596         if all(isinstance(dtype, np.dtype) for dtype in dtypes_orig):
# --> 597             dtype_orig = np.result_type(*dtypes_orig)
#     598
#     599     if dtype_numeric:
#
# <__array_function__ internals> in result_type(*args, **kwargs)
#
# TypeError: invalid type promotion

# %%
train_y = train["Valeur fonciere"]
test_y = test["Valeur fonciere"]

# %%
pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC())])
pipe.fit(train_x, train_y)
pipe.score(test_x, test_y)

# %%
regr = regression(train_x, train_y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: float() argument must be a string or a number, not 'csr_matrix'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-ea6d3d32b3e7> in <module>
# ----> 1 regr = regression(train_x, train_y)
#
# ~\PycharmProjects\Projet-VF\projet_vf\model.py in regression(train_x, train_y)
#       6
#       7     regr = RandomForestRegressor(n_estimators=200, max_depth=5, random_state=100)
# ----> 8     regression = regr.fit(train_x, train_y)
#       9     for name, feature in zip(
#      10         [
#
# c:\users\evaga\anaconda3\envs\projet-dvf\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     302                 "sparse multilabel-indicator for y is not supported."
#     303             )
# --> 304         X, y = self._validate_data(X, y, multi_output=True,
#     305                                    accept_sparse="csc", dtype=DTYPE)
#     306         if sample_weight is not None:
#
# c:\users\evaga\anaconda3\envs\projet-dvf\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# c:\users\evaga\anaconda3\envs\projet-dvf\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# c:\users\evaga\anaconda3\envs\projet-dvf\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     869         raise ValueError("y cannot be None")
#     870
# --> 871     X = check_array(X, accept_sparse=accept_sparse,
#     872                     accept_large_sparse=accept_large_sparse,
#     873                     dtype=dtype, order=order, copy=copy,
#
# c:\users\evaga\anaconda3\envs\projet-dvf\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# c:\users\evaga\anaconda3\envs\projet-dvf\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     671                     array = array.astype(dtype, casting="unsafe", copy=False)
#     672                 else:
# --> 673                     array = np.asarray(array, order=order, dtype=dtype)
#     674             except ComplexWarning as complex_warning:
#     675                 raise ValueError("Complex data not supported\n"
#
# c:\users\evaga\anaconda3\envs\projet-dvf\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ValueError: setting an array element with a sequence.

# %%
"""Le critères le plus important pour prédire la valeur d'un bien à Paris est l'arrondissement, la saisonnalité ou le type de bien n'influencent pas le modèle"""
# Out:
# "Le critères le plus important pour prédire la valeur d'un bien à Paris est l'arrondissement, la saisonnalité ou le type de bien n'influencent pas le modèle"

# %%
prediction_regr = regr.predict(test_x)
errors_regr = abs(prediction_regr - test_y)
print('Mean Absolute Error regr:', round(np.mean(errors_regr), 2), 'euros.')
# Out:
# Mean Absolute Error regr: 126821.85 euros.

# %%
from sklearn.metrics import r2_score
r2 = r2_score(test_y, prediction_regr)
print('r2 score for perfect model is', r2)

# %%
'''Notre model n'est pas performant car il n'y a pas assez de données et certaines données n'ont pas pu être correctement exploitées'''
# Out:
# "Notre model n'est pas performant car il n'y a pas assez de données et certaines données n'ont pas pu être correctement exploitées"

# %%
from sk
