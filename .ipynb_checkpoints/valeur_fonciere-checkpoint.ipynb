# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from model import regression
from sklearn.model_selection import train_test_split
from data_loader import load_house_attributes
from data_sources import source_choice
from processing_attributes import process_house_attributes

# %%
df = source_choice()

# %%
df_paris = load_house_attributes(df)

# %%
df_paris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 277389 entries, 0 to 313775
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   No disposition             277389 non-null  int32
#  1   Date mutation              277389 non-null  datetime64[ns]
#  2   Nature mutation            277389 non-null  object
#  3   Valeur fonciere            277389 non-null  float64
#  4   Type de voie               277389 non-null  object
#  5   Code postal                277389 non-null  float64
#  6   Commune                    277389 non-null  object
#  7   Code departement           277389 non-null  object
#  8   Code commune               277389 non-null  int32
#  9   Section                    277389 non-null  object
#  10  Nombre de lots             277389 non-null  int32
#  11  Type local                 277389 non-null  object
#  12  Surface reelle bati        277389 non-null  float64
#  13  Nombre pieces principales  277389 non-null  float64
#  14  year                       277389 non-null  int64
#  15  months                     277389 non-null  int64
#  16  day                        277389 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int32(3), int64(3), object(6)
# memory usage: 34.9+ MB

# %%
df_paris.describe()
# Out:
#        No disposition  Valeur fonciere    Code postal   Code commune  \
# count   277389.000000     2.773890e+05  277389.000000  277389.000000
# mean         1.013360     6.272351e+05   75013.380635     113.380635
# std          0.211639     7.493948e+05       4.786666       4.786666
# min          1.000000     0.000000e+00   75001.000000     101.000000
# 25%          1.000000     1.986000e+05   75010.000000     110.000000
# 50%          1.000000     3.902310e+05   75015.000000     115.000000
# 75%          1.000000     7.402300e+05   75017.000000     117.000000
# max         24.000000     5.000000e+06   75020.000000     120.000000
#
#        Nombre de lots  Surface reelle bati  Nombre pieces principales  \
# count   277389.000000        277389.000000              277389.000000
# mean         1.476151            40.089506                   1.591271
# std          0.966125            42.149696                   1.520258
# min          0.000000             0.000000                   0.000000
# 25%          1.000000             0.000000                   0.000000
# 50%          1.000000            31.000000                   1.000000
# 75%          2.000000            57.000000                   3.000000
# max         51.000000           299.000000                  10.000000
#
#                 year         months            day
# count  277389.000000  277389.000000  277389.000000
# mean     2017.975861       6.716005      16.763296
# std         1.365407       3.429718       8.855287
# min      2016.000000       1.000000       1.000000
# 25%      2017.000000       4.000000       9.000000
# 50%      2018.000000       7.000000      17.000000
# 75%      2019.000000      10.000000      25.000000
# max      2020.000000      12.000000      31.000000

# %%
plt.figure(figsize=(10, 10))
sns.pairplot(df_paris[['Valeur fonciere', 'Surface reelle bati', 'Nombre pieces principales', 'Type local']],
             hue='Type local')
# Out:
# C:\Users\evaga\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
sns.countplot(x="year", data=df_paris)

# %%
corr = df_paris.corr()
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
train, test = train_test_split(df_paris, test_size=0.25, random_state=42)

# %%
print('Training Shape:', train.shape)
print('Testing Shape:', test.shape)
# Out:
# Training Shape: (208041, 17)
# Testing Shape: (69348, 17)

# %%
train_x, test_x = process_house_attributes(df_paris, train, test)

# %%
train_y = train["Valeur fonciere"]
test_y = test["Valeur fonciere"]

# %%
regr = regression(train_x, train_y)
# Out:
# months 3.9
# day 3.7
# No disposition 0.9
# Nombre de lots 2.3
# Surface reelle bati 0.1
# Nombre pieces principales 45.1
# Commune 43.1
# Type local 0.8

# %%
"""Les critères les plus importants pour prédire la valeur d'un bien à Paris sont le quartier (section) et le nombre de pièces, la saisonnalité ou le type de bien n'influencent pas le modèle"""
# Out:
# "Les critères les plus importants pour prédire la valeur d'un bien à Paris sont le quartier (section) et le nombre de pièces, la saisonnalité ou le type de bien n'influencent pas le modèle"

# %%
prediction_regr = regr.predict(test_x)
errors_regr = abs(prediction_regr - test_y)
print('Mean Absolute Error regr:', round(np.mean(errors_regr), 2), 'euros.')
# Out:
# Mean Absolute Error regr: 338832.18 euros.

# %%
'''Notre model n'est pas performant car il n'y a pas assez de données et certaines données n'ont pas pu être correctement exploitées (Surface et nb de pièce qui sont très corrélées)'''
# Out:
# "Notre model n'est pas performant car il n'y a pas assez de données et certaines données n'ont pas pu être correctement exploitées (Surface et nb de pièce qui sont très corrélées)"
