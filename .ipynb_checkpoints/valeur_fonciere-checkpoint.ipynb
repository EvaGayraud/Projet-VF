# %%
import pandas as pd
import numpy as np
import seaborn as sns
from data_loader import load_house_attributes
from data_loader import get_subsample

# %%
df = get_subsample()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))

# %%
df_paris = load_house_attributes(df)

# %%
df_paris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186223 entries, 2405430 to 2939477
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   No disposition             186223 non-null  int64
#  1   Date mutation              186223 non-null  datetime64[ns]
#  2   Nature mutation            186223 non-null  object
#  3   Valeur fonciere            186223 non-null  float64
#  4   Type de voie               186223 non-null  object
#  5   Code postal                186223 non-null  object
#  6   Commune                    186223 non-null  object
#  7   Code departement           186223 non-null  object
#  8   Code commune               186223 non-null  int64
#  9   Section                    186223 non-null  object
#  10  Nombre de lots             186223 non-null  int64
#  11  Type local                 186223 non-null  object
#  12  Surface reelle bati        186223 non-null  float64
#  13  Nombre pieces principales  186223 non-null  int32
#  14  year                       186223 non-null  int64
#  15  months                     186223 non-null  int64
#  16  day                        186223 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int32(1), int64(6), object(7)
# memory usage: 24.9+ MB

# %%
df_paris.describe()
# Out:
#        No disposition  Valeur fonciere   Code commune  Nombre de lots  \
# count   186223.000000     1.862230e+05  186223.000000   186223.000000
# mean         1.011771     6.159931e+05     113.386375        1.614043
# std          0.209716     6.819367e+05       4.861405        0.857624
# min          1.000000     0.000000e+00     101.000000        0.000000
# 25%          1.000000     2.430000e+05     110.000000        1.000000
# 50%          1.000000     4.050000e+05     115.000000        2.000000
# 75%          1.000000     7.000000e+05     117.000000        2.000000
# max         24.000000     5.000000e+06     120.000000       27.000000
#
#        Surface reelle bati  Nombre pieces principales           year  \
# count        186223.000000              186223.000000  186223.000000
# mean             52.442776                   2.381430    2017.968656
# std              38.772383                   1.282874       1.371121
# min               5.000000                   1.000000    2016.000000
# 25%              27.000000                   1.000000    2017.000000
# 50%              42.000000                   2.000000    2018.000000
# 75%              66.000000                   3.000000    2019.000000
# max             631.000000                  20.000000    2020.000000
#
#               months            day
# count  186223.000000  186223.000000
# mean        6.688733      16.731123
# std         3.413852       8.877029
# min         1.000000       1.000000
# 25%         4.000000       9.000000
# 50%         7.000000      17.000000
# 75%        10.000000      25.000000
# max        12.000000      31.000000

# %%
df_paris['Commune'].value_counts()
# Out:
# PARIS 18    20811
# PARIS 15    18867
# PARIS 17    16206
# PARIS 16    16086
# PARIS 11    14766
# PARIS 20    12269
# PARIS 19    11228
# PARIS 10     9855
# PARIS 12     9854
# PARIS 14     9738
# PARIS 13     8649
# PARIS 09     6703
# PARIS 07     5157
# PARIS 06     4769
# PARIS 05     4659
# PARIS 08     4282
# PARIS 03     4231
# PARIS 04     3101
# PARIS 02     2985
# PARIS 01     2007
# Name: Commune, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
sns.pairplot(df_paris[['Valeur fonciere','Surface reelle bati','Nombre pieces principales','Type local']], hue='Type local')

# %%
sns.countplot(x="year", data=df_paris)

# %%
corr = df_paris.corr()
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(df_paris, test_size=0.2, random_state=42)

# %%
print('Training Shape:', train.shape)
print('Testing Shape:', test.shape)
# Out:
# Training Shape: (148978, 17)
# Testing Shape: (37245, 17)

# %%
from processing_attributes import process_house_attributes

# %%
train_x, test_x = process_house_attributes(df_paris, train, test)

# %%
train_y = train["Valeur fonciere"] 
test_y = test["Valeur fonciere"]

# %%
from model import regression

# %%
regr = regression(train_x, train_y)
# Out:
# months 3.1
# day 0.1
# No disposition 2.7
# Nombre de lots 0.4
# Surface reelle bati 0.4
# Nombre pieces principales 1.1
# Code postal 0.0
# Type local 38.8
# Section 53.3
# Type de voie 0.0

# %%
"""Les critères les plus importants pour prédire la valeur d'un bien à Paris sont le quartier (Section) et le type de bien, la saisonnalité ou le nombre de pièce n'influencent pas le modèle"""
# Out:
# "Les critères les plus importants pour prédire la valeur d'un bien à Paris sont le quartier (Section) et le type de bien, la saisonnalité ou le nombre de pièce n'influencent pas le modèle"

# %%
prediction_regr = regr.predict(test_x)
errors_regr = abs(prediction_regr - test_y)
print('Mean Absolute Error regr:', round(np.mean(errors_regr), 2), 'euros.')
# Out:
# Mean Absolute Error regr: 219245.42 euros.

# %%
value = round(np.mean(errors_regr), 2)

# %%
'''Notre model n'est pas performant car il n'y a pas assez de données et certaines données n'ont pas pu être correctement exploitées (Surface et nb de pièce qui sont très corrélées)'''
# Out:
# "Notre model n'est pas performant car il n'y a pas assez de données et certaines données n'ont pas pu être correctement exploitées (Surface et nb de pièce qui sont très corrélées)"
