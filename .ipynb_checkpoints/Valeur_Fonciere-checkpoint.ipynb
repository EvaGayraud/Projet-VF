# %%
import pandas as pd
import numpy as np
import seaborn as sns
from data_loader import load_house_attributes
from data_loader import get_subsample

# %%
df = get_subsample()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# C:\Users\evaga\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3263: DtypeWarning: Columns (14,18,23,24,26,28,31,33,41) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# C:\Users\evaga\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3263: DtypeWarning: Columns (18,23,24,26,28,29,31,33,41) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# C:\Users\evaga\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3263: DtypeWarning: Columns (18,23,24,26,28,29,31,32,33,41) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# C:\Users\evaga\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3263: DtypeWarning: Columns (18,23,24,26,28,31,33,41) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# C:\Users\evaga\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3263: DtypeWarning: Columns (18,23,24,26,28,30,31,32,33,41) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
df_paris = load_house_attributes(df)

# %%
df_paris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   No disposition             0 non-null      int64
#  1   Date mutation              0 non-null      datetime64[ns]
#  2   Nature mutation            0 non-null      object
#  3   Valeur fonciere            0 non-null      float64
#  4   Type de voie               0 non-null      object
#  5   Code postal                0 non-null      object
#  6   Commune                    0 non-null      object
#  7   Code departement           0 non-null      object
#  8   Code commune               0 non-null      int64
#  9   Section                    0 non-null      object
#  10  Nombre de lots             0 non-null      int64
#  11  Type local                 0 non-null      object
#  12  Surface reelle bati        0 non-null      float64
#  13  Nombre pieces principales  0 non-null      int32
#  14  year                       0 non-null      int64
#  15  months                     0 non-null      int64
#  16  day                        0 non-null      int64
# dtypes: datetime64[ns](1), float64(2), int32(1), int64(6), object(7)
# memory usage: 0.0+ bytes

# %%
df_paris.describe()
# Out:
#        No disposition  Valeur fonciere  Code commune  Nombre de lots  \
# count    32441.000000     3.244100e+04  32441.000000    32441.000000
# mean         1.008693     6.783287e+05    113.341358        1.608520
# std          0.098938     7.275251e+05      4.886327        0.858988
# min          1.000000     1.500000e-01    101.000000        0.000000
# 25%          1.000000     2.750000e+05    110.000000        1.000000
# 50%          1.000000     4.540000e+05    115.000000        2.000000
# 75%          1.000000     7.776000e+05    117.000000        2.000000
# max          4.000000     5.000000e+06    120.000000       21.000000
#
#        Surface reelle bati  Nombre pieces principales     year        months  \
# count         32441.000000               32441.000000  32441.0  32441.000000
# mean             51.927098                   2.376807   2020.0      6.646034
# std              38.414929                   1.271400      0.0      3.590156
# min               5.000000                   1.000000   2020.0      1.000000
# 25%              27.000000                   1.000000   2020.0      3.000000
# 50%              42.000000                   2.000000   2020.0      7.000000
# 75%              65.000000                   3.000000   2020.0     10.000000
# max             469.000000                  17.000000   2020.0     12.000000
#
#                 day
# count  32441.000000
# mean      16.854505
# std        8.953902
# min        1.000000
# 25%        9.000000
# 50%       17.000000
# 75%       25.000000
# max       31.000000

# %%
df_paris['Commune'].value_counts()
# Out:
# PARIS 18    3604
# PARIS 15    3229
# PARIS 16    2756
# PARIS 17    2741
# PARIS 11    2602
# PARIS 20    2170
# PARIS 19    1969
# PARIS 10    1808
# PARIS 12    1742
# PARIS 14    1706
# PARIS 13    1420
# PARIS 09    1209
# PARIS 07     898
# PARIS 05     858
# PARIS 06     826
# PARIS 03     745
# PARIS 08     717
# PARIS 04     567
# PARIS 02     520
# PARIS 01     354
# Name: Commune, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
sns.pairplot(df_paris[['Valeur fonciere','Surface reelle bati','Nombre pieces principales','Type local']], hue='Type local')

# %%
sns.countplot(x="months", data=df_paris)

# %%
corr = df_paris.corr()
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(df_paris, test_size=0.2, random_state=42)

# %%
print('Training Shape:', train.shape)
print('Testing Shape:', test.shape)
# Out:
# Training Shape: (25952, 17)
# Testing Shape: (6489, 17)

# %%
from processing_attributes import process_house_attributes

# %%
train_x, test_x = process_house_attributes(df_paris, train, test)

# %%
train_y = train["Valeur fonciere"] 
test_y = test["Valeur fonciere"]

# %%
from model import regression

# %%
regr = regression(train_x, train_y)
# Out:
# months 7.1
# day 0.2
# No disposition 6.4
# Nombre de lots 0.8
# Surface reelle bati 0.4
# Nombre pieces principales 2.8
# Code postal 0.1
# Type local 32.4
# Section 49.7
# Type de voie 0.1

# %%
"""Les critères les plus importants pour prédire la valeur d'un bien à Paris sont le quartier (Section) et le type de bien, la saisonnalité ou le nombre de pièce n'influencent pas le modèle"""
# Out:
# "Les critères les plus importants pour prédire la valeur d'un bien à Paris sont le quartier (Section) et le type de bien, la saisonnalité ou le nombre de pièce n'influencent pas le modèle"

# %%
prediction_regr = regr.predict(test_x)
errors_regr = abs(prediction_regr - test_y)
print('Mean Absolute Error regr:', round(np.mean(errors_regr), 2), 'euros.')
# Out:
# Mean Absolute Error regr: 226230.92 euros.

# %%
value = round(np.mean(errors_regr), 2)

# %%
'''Notre model n'est pas performant car il n'y a pas assez de données et certaines données n'ont pas pu être correctement exploitées (Surface et nb de pièce qui sont très corrélées)'''
# Out:
# "Notre model n'est pas performant car il n'y a pas assez de données et certaines données n'ont pas pu être correctement exploitées (Surface et nb de pièce qui sont très corrélées)"
